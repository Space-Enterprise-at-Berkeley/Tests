# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from filterpy.kalman import KalmanFilter

# %%
PROP_ACCELERATE = 0.2
DISTURBANCE_MAGNITUDE = 0.005
TERMINAL_VELOCITY = -20
g = -9.8

def update(x_0, v, a, delta_t):
    val = x_0 + v*delta_t+(a*delta_t**2)/2
    #print("{}, {}, {}".format(val, disturbance_factor, val*disturbance_factor))
    velocity = (val - x_0) / delta_t
    if(val > 1000):
        disturbance = random.uniform(-1,1)*DISTURBANCE_MAGNITUDE*val
        #val += disturbance
    return val, velocity

DELTA_T = 0.1 #interval in seconds

def generate_data(length):
    altitude = []
    x = 0
    velocity = 0
    a_0 = 3.6 * 10**3 / 100
    for i in range(int(length / DELTA_T)):
        if (x < 0):
            break
        if (i < length * PROP_ACCELERATE / DELTA_T):
           # print("accelerating")
            x, velocity = update(x, velocity, a_0+g, DELTA_T)
            altitude.append(x)
        else:
            #print("decelarating")
            x, velocity = update(x, velocity, g, DELTA_T)
            altitude.append(x)
    return altitude

# %%
length = 20000 # time period in s
altitude = generate_data(length)

plt.plot(np.arange(len(altitude)), altitude)
#ax.set_xticks(range(length))

# %%
velocity = [(altitude[i+1] - altitude[i])/DELTA_T for i in range(len(altitude)-1)]
plt.plot(range(len(velocity)), velocity)

# %%
def kalman(data):
    estimate = []
    estimatenp.mean(data)}
    velocity = 0
    resid = []
    mse = {np.std(data)}
    k = []
    filtered = []
    for j in range(len(data)-1):
        i = j+1
        estimate.append(data[i-1] + velocity* DELTA_T + g * DELTA_T**2 /2)
        velocity = (data[i] - data[i-1]) / DELTA_T
        resid.append(curr - estimate)
        k.append(abs(resid / (resid + 1)))
        #print("k: {}, resid: {}".format(k,resid))
        finalEstimate = estimate + k * resid
        filtered.append(finalEstimate)
    return filtered

# %%
filtered_data = kalman(altitude)
plt.plot(np.arange(len(filtered_data)), filtered_data)
plt.plot(np.arange(len(altitude)), altitude)
diff = np.asarray(altitude) - np.asarray(filtered_data)
print("mu: {}, std: {}".format(np.mean(diff), np.std(diff)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-6c9695941532> in <module>
# ----> 1 filtered_data = kalman(altitude)
#       2 plt.plot(np.arange(len(filtered_data)), filtered_data)
#       3 plt.plot(np.arange(len(altitude)), altitude)
#       4 diff = np.asarray(altitude) - np.asarray(filtered_data)
#       5 print("mu: {}, std: {}".format(np.mean(diff), np.std(diff)))
#
# <ipython-input-115-5920a569795b> in kalman(data)
#       8     for j in range(len(data)-1):
#       9         i = j+1
# ---> 10         estimate.append(data[i-1] + velocity* DELTA_T + g * DELTA_T**2 /2)
#      11         velocity = (data[i] - data[i-1]) / DELTA_T
#      12         resid.append(curr - estimate)
#
# AttributeError: 'set' object has no attribute 'append'

# %%
def Apogee(data):
    for j in range(len(data)-3):
        i = j + 2
        if(data[i] < data[i-1] and data[i-1] < data[i-2]):
            return i
    return -1

# %%
apogee = Apogee(altitude)
plt.plot(np.arange(len(altitude)), altitude)
plt.axvline(apogee)
